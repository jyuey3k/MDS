# %%
import networkx as nx
G=nx.Graph()

# %%
G.add_node(1)

# %%
G.add_edge(1,2)

# %%
print(G.number_of_nodes())
print(G.number_of_edges())
# Out:
# 2
# 1

# %%
nx.connected_components(G)
# Out:
# <generator object connected_components at 0x7f9d1bd1d048>

# %%
nx.clustering(G)
# Out:
# {1: 0, 2: 0}

# %%
nx.degree(G)
# Out:
# DegreeView({1: 1, 2: 1})

# %%
import matplotlib.pyplot as plt

# %%
G=nx.karate_club_graph()

# %%
nx.draw(G)

# %%
nx.draw_random(G)

# %%
nx.draw_circular(G)

# %%
nx.draw_spring(G)
